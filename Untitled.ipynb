# %%
import pandas as pd
import numpy as np
import seaborn as sns
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
populationData1 = pd.read_csv("populationData1.csv");
populationData2 = pd.read_csv("populationDataChange2018to2019.csv")

populationData2.head()
# Out:
#   table with row headers in column A and column headers in rows 3 through 4 (leading dots indicate sub-parts)  \
# 0  Annual Estimates of the Resident Population fo...
# 1                                    Geographic Area
# 2                                                NaN
# 3                                           Illinois
# 4                            .Adams County, Illinois
#
#       Unnamed: 1      Unnamed: 2                          Unnamed: 3  \
# 0            NaN             NaN                                 NaN
# 1  April 1, 2010             NaN  Population Estimate (as of July 1)
# 2         Census  Estimates Base                                2010
# 3     12,830,632      12,831,572                          12,840,503
# 4         67,103          67,097                              67,160
#
#    Unnamed: 4  Unnamed: 5  Unnamed: 6  Unnamed: 7  Unnamed: 8  Unnamed: 9  \
# 0         NaN         NaN         NaN         NaN         NaN         NaN
# 1         NaN         NaN         NaN         NaN         NaN         NaN
# 2        2011        2012        2013        2014        2015        2016
# 3  12,867,454  12,882,510  12,895,129  12,884,493  12,858,913  12,820,527
# 4      67,211      67,139      66,999      66,966      66,835      66,475
#
#   Unnamed: 10 Unnamed: 11 Unnamed: 12
# 0         NaN         NaN         NaN
# 1         NaN         NaN         NaN
# 2        2017        2018        2019
# 3  12,778,828  12,723,071  12,671,821
# 4      66,057      65,623      65,435
